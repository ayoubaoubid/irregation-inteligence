# %%
import pandas as pd
import numpy as np

# %%
# comme chiois 1: df = pd.read_csv('irrigation_prediction.csv')
#df = pd.read_csv('irrigation_prediction_processed.csv')

df = pd.read_csv('irrigation_prediction_Variables_Important.csv')
df.head()
# Out:
#    Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0     6.14          36.48            0.42                     2.17
# 1     6.41          50.56            0.38                     0.23
# 2     7.71          40.07            1.09                     2.18
# 3     5.96          12.75            1.56                     0.40
# 4     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
#   Crop_Growth_Stage Irrigation_Type  Field_Area_hectare Mulching_Used  \
# ...

# %%
df.columns
# Out:
# Index(['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity',
#        'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours',
#        'Wind_Speed_kmh', 'Crop_Growth_Stage', 'Irrigation_Type',
#        'Field_Area_hectare', 'Mulching_Used', 'Previous_Irrigation_mm',
#        'Irrigation_Need'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Soil_pH                  10000 non-null  float64
#  1   Soil_Moisture            10000 non-null  float64
#  2   Organic_Carbon           10000 non-null  float64
#  3   Electrical_Conductivity  10000 non-null  float64
#  4   Temperature_C            10000 non-null  float64
#  5   Humidity                 10000 non-null  float64
#  6   Rainfall_mm              10000 non-null  float64
#  7   Sunlight_Hours           10000 non-null  float64
#  8   Wind_Speed_kmh           10000 non-null  float64
#  9   Crop_Growth_Stage        10000 non-null  str
#  10  Irrigation_Type          10000 non-null  str
#  11  Field_Area_hectare       10000 non-null  float64
#  12  Mulching_Used            10000 non-null  str
#  13  Previous_Irrigation_mm   10000 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
#        'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm',
#        'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage',
#        'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare',
#        'Mulching_Used', 'Previous_Irrigation_mm', 'Region', 'Irrigation_Need'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity',
#        'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours',
#        'Wind_Speed_kmh', 'Crop_Growth_Stage', 'Irrigation_Type',
#        'Field_Area_hectare', 'Mulching_Used', 'Previous_Irrigation_mm',
#        'Irrigation_Need'],
#       dtype='object')

# %%
df['Crop_Growth_Stage'].value_counts()
# Out:
# Crop_Growth_Stage
# Harvest       2581
# Vegetative    2521
# Flowering     2465
# Sowing        2433
# Name: count, dtype: int64

# %%
df_1 = pd.read_csv('irrigation_prediction_processed.csv')
len(df_1.columns)
# Out:
# 19

# %%
for i in df.columns:
    for j in df_1.columns:
        
        if i==j :
            print(i)
# Out:
# Soil_pH
# Soil_Moisture
# Organic_Carbon
# Electrical_Conductivity
# Temperature_C
# Humidity
# Rainfall_mm
# Sunlight_Hours
# Wind_Speed_kmh
# Field_Area_hectare
# Previous_Irrigation_mm
# Irrigation_Need
